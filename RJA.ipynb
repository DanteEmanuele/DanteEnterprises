# %% [markdown]
# <a href="https://colab.research.google.com/github/DanteEmanuele/DanteEnterprises/blob/main/RJA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/PersonHasCaseDatar.csv')

df
# Out:
#      PersonID            PersonDOB               Gender        Ethnicity  \
# 0        3001  1978-04-11 00:00:00                Woman  White - British
# 1        3002  1998-02-14 00:00:00                  NaN       Not stated
# 2        3003  2022-06-24 00:00:00                  NaN       Not stated
# 3        3004  2022-06-24 00:00:00                  NaN       Not stated
# 4        3005  2022-06-24 00:00:00                  NaN       Not stated
# ..        ...                  ...                  ...              ...
# 504      3493  1969-12-22 00:00:00  -- Please Select --       Not stated
# 505      3494  1994-03-31 00:00:00                Woman  White - British
# 506      3495  1982-01-22 00:00:00    Prefer not to say  White - British
# 507      3496  1963-01-29 00:00:00  -- Please Select --       Not stated
# 508      3497  1999-08-01 00:00:00                Woman       Not stated
#
#                  Disability1    SexualOrientation  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509 entries, 0 to 508
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   PersonID                     509 non-null    int64
#  1   PersonDOB                    509 non-null    object
#  2   Gender                       447 non-null    object
#  3   Ethnicity                    507 non-null    object
#  4   Disability1                  509 non-null    object
#  5   SexualOrientation            509 non-null    object
#  6   Disability2                  509 non-null    object
#  7   Disability3                  509 non-null    object
#  8   FirstLanguage                161 non-null    object
#  9   Religion                     161 non-null    object
#  10  Pronouns                     161 non-null    object
#  11  PersonRequiresInterpreter    509 non-null    int64
#  12  PersonDependantChildren      509 non-null    int64
# ...

# %%
df = df.dropna(thresh=len(df) * 0.8, axis=1)

df
# Out:
#      PersonID            PersonDOB               Gender        Ethnicity  \
# 0        3001  1978-04-11 00:00:00                Woman  White - British
# 1        3002  1998-02-14 00:00:00                  NaN       Not stated
# 2        3003  2022-06-24 00:00:00                  NaN       Not stated
# 3        3004  2022-06-24 00:00:00                  NaN       Not stated
# 4        3005  2022-06-24 00:00:00                  NaN       Not stated
# ..        ...                  ...                  ...              ...
# 504      3493  1969-12-22 00:00:00  -- Please Select --       Not stated
# 505      3494  1994-03-31 00:00:00                Woman  White - British
# 506      3495  1982-01-22 00:00:00    Prefer not to say  White - British
# 507      3496  1963-01-29 00:00:00  -- Please Select --       Not stated
# 508      3497  1999-08-01 00:00:00                Woman       Not stated
#
#                  Disability1    SexualOrientation  \
# ...

# %%
df['PersonRequiresInterpreter'] = df['PersonRequiresInterpreter'].astype('Int64')
df['PersonDependantChildren'] = df['PersonDependantChildren'].astype('Int64')

df
# Out:
#      PersonID            PersonDOB               Gender        Ethnicity  \
# 0        3001  1978-04-11 00:00:00                Woman  White - British
# 1        3002  1998-02-14 00:00:00                  NaN       Not stated
# 2        3003  2022-06-24 00:00:00                  NaN       Not stated
# 3        3004  2022-06-24 00:00:00                  NaN       Not stated
# 4        3005  2022-06-24 00:00:00                  NaN       Not stated
# ..        ...                  ...                  ...              ...
# 504      3493  1969-12-22 00:00:00  -- Please Select --       Not stated
# 505      3494  1994-03-31 00:00:00                Woman  White - British
# 506      3495  1982-01-22 00:00:00    Prefer not to say  White - British
# 507      3496  1963-01-29 00:00:00  -- Please Select --       Not stated
# 508      3497  1999-08-01 00:00:00                Woman       Not stated
#
#                  Disability1    SexualOrientation  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509 entries, 0 to 508
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PersonID                   509 non-null    int64
#  1   PersonDOB                  509 non-null    object
#  2   Gender                     447 non-null    object
#  3   Ethnicity                  507 non-null    object
#  4   Disability1                509 non-null    object
#  5   SexualOrientation          509 non-null    object
#  6   Disability2                509 non-null    object
#  7   Disability3                509 non-null    object
#  8   PersonRequiresInterpreter  509 non-null    Int64
#  9   PersonDependantChildren    509 non-null    Int64
#  10  RelationshipToCase         504 non-null    object
# dtypes: Int64(2), int64(1), object(8)
# memory usage: 44.9+ KB

# %%
df
# Out:
#      PersonID   PersonDOB               Gender        Ethnicity  \
# 0        3001  1978-04-11                Woman  White - British
# 1        3002  1998-02-14                  NaN       Not stated
# 2        3003  2022-06-24                  NaN       Not stated
# 3        3004  2022-06-24                  NaN       Not stated
# 4        3005  2022-06-24                  NaN       Not stated
# ..        ...         ...                  ...              ...
# 504      3493  1969-12-22  -- Please Select --       Not stated
# 505      3494  1994-03-31                Woman  White - British
# 506      3495  1982-01-22    Prefer not to say  White - British
# 507      3496  1963-01-29  -- Please Select --       Not stated
# 508      3497  1999-08-01                Woman       Not stated
#
#                  Disability1    SexualOrientation  \
# 0    Mental Health Condition           Not stated
# 1           Please Select...           Not stated
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509 entries, 0 to 508
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PersonID                   509 non-null    int64
#  1   PersonDOB                  498 non-null    datetime64[ns]
#  2   Gender                     447 non-null    object
#  3   Ethnicity                  507 non-null    object
#  4   Disability1                509 non-null    object
#  5   SexualOrientation          509 non-null    object
#  6   Disability2                509 non-null    object
#  7   Disability3                509 non-null    object
#  8   PersonRequiresInterpreter  509 non-null    Int64
#  9   PersonDependantChildren    509 non-null    Int64
#  10  RelationshipToCase         504 non-null    object
# dtypes: Int64(2), datetime64[ns](1), int64(1), object(7)
# memory usage: 44.9+ KB

# %%
df
# Out:
#      PersonID  PersonDOB               Gender        Ethnicity  \
# 0        3001 1978-04-11                Woman  White - British
# 1        3002 1998-02-14                  NaN       Not stated
# 2        3003 2022-06-24                  NaN       Not stated
# 3        3004 2022-06-24                  NaN       Not stated
# 4        3005 2022-06-24                  NaN       Not stated
# ..        ...        ...                  ...              ...
# 504      3493 1969-12-22  -- Please Select --       Not stated
# 505      3494 1994-03-31                Woman  White - British
# 506      3495 1982-01-22    Prefer not to say  White - British
# 507      3496 1963-01-29  -- Please Select --       Not stated
# 508      3497 1999-08-01                Woman       Not stated
#
#                  Disability1    SexualOrientation  \
# 0    Mental Health Condition           Not stated
# 1           Please Select...           Not stated
# 2           Please Select...           Not stated
# ...

# %%
#df['RelationshipToCase'] = df['RelationshipToCase'].replace('-- Please Select --', pd.NA)
df
# Out:
#      PersonID  PersonDOB               Gender        Ethnicity  \
# 0        3001 1978-04-11                Woman  White - British
# 1        3002 1998-02-14                  NaN       Not stated
# 2        3003 2022-06-24                  NaN       Not stated
# 3        3004 2022-06-24                  NaN       Not stated
# 4        3005 2022-06-24                  NaN       Not stated
# ..        ...        ...                  ...              ...
# 504      3493 1969-12-22  -- Please Select --       Not stated
# 505      3494 1994-03-31                Woman  White - British
# 506      3495 1982-01-22    Prefer not to say  White - British
# 507      3496 1963-01-29  -- Please Select --       Not stated
# 508      3497 1999-08-01                Woman       Not stated
#
#                  Disability1    SexualOrientation  \
# 0    Mental Health Condition           Not stated
# 1           Please Select...           Not stated
# 2           Please Select...           Not stated
# ...

# %%
df['SexualOrientation'] = df['SexualOrientation'].replace('-- Please Select --', pd.NA)

# %%
df['Disability1'] = df['Disability1'].replace('Please Select...', pd.NA)

# %%
df['Disability2'] = df['Disability2'].replace('Please Select...', pd.NA)

# %%
df['Disability3'] = df['Disability3'].replace('Please Select...', pd.NA)

# %%
column_name = 'Disability1'
new_pos = 5
column_to_move = df.pop('Disability1')
df.insert(new_pos, column_name, column_to_move)

# %%
df
# Out:
#      PersonID  PersonDOB               Gender        Ethnicity  \
# 0        3001 1978-04-11                Woman  White - British
# 1        3002 1998-02-14                  NaN       Not stated
# 2        3003 2022-06-24                  NaN       Not stated
# 3        3004 2022-06-24                  NaN       Not stated
# 4        3005 2022-06-24                  NaN       Not stated
# ..        ...        ...                  ...              ...
# 504      3493 1969-12-22  -- Please Select --       Not stated
# 505      3494 1994-03-31                Woman  White - British
# 506      3495 1982-01-22    Prefer not to say  White - British
# 507      3496 1963-01-29  -- Please Select --       Not stated
# 508      3497 1999-08-01                Woman       Not stated
#
#      SexualOrientation              Disability1  \
# 0           Not stated  Mental Health Condition
# 1           Not stated                     <NA>
# 2           Not stated                     <NA>
# ...

# %%
df['Gender'] = df['Gender'].replace('-- Please Select --', pd.NA)

# %%
df
# Out:
#      PersonID  PersonDOB             Gender        Ethnicity  \
# 0        3001 1978-04-11              Woman  White - British
# 1        3002 1998-02-14                NaN       Not stated
# 2        3003 2022-06-24                NaN       Not stated
# 3        3004 2022-06-24                NaN       Not stated
# 4        3005 2022-06-24                NaN       Not stated
# ..        ...        ...                ...              ...
# 504      3493 1969-12-22               <NA>       Not stated
# 505      3494 1994-03-31              Woman  White - British
# 506      3495 1982-01-22  Prefer not to say  White - British
# 507      3496 1963-01-29               <NA>       Not stated
# 508      3497 1999-08-01              Woman       Not stated
#
#      SexualOrientation              Disability1  \
# 0           Not stated  Mental Health Condition
# 1           Not stated                     <NA>
# 2           Not stated                     <NA>
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509 entries, 0 to 508
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PersonID                   509 non-null    int64
#  1   PersonDOB                  498 non-null    datetime64[ns]
#  2   Gender                     384 non-null    object
#  3   Ethnicity                  507 non-null    object
#  4   SexualOrientation          393 non-null    object
#  5   Disability1                95 non-null     object
#  6   Disability2                27 non-null     object
#  7   Disability3                10 non-null     object
#  8   PersonRequiresInterpreter  509 non-null    Int64
#  9   PersonDependantChildren    509 non-null    Int64
#  10  RelationshipToCase         496 non-null    object
# dtypes: Int64(2), datetime64[ns](1), int64(1), object(7)
# memory usage: 44.9+ KB

# %%
df_index = df.set_index('PersonID')

# %%
df.head()
# Out:
#    PersonID  PersonDOB Gender        Ethnicity SexualOrientation  \
# 0      3001 1978-04-11  Woman  White - British        Not stated
# 1      3002 1998-02-14    NaN       Not stated        Not stated
# 2      3003 2022-06-24    NaN       Not stated        Not stated
# 3      3004 2022-06-24    NaN       Not stated        Not stated
# 4      3005 2022-06-24    NaN       Not stated        Not stated
#
#                Disability1                                     Disability2  \
# 0  Mental Health Condition  Physical impairment such as difficulty walking
# 1                     <NA>                                            <NA>
# 2                     <NA>                                            <NA>
# 3                     <NA>                                            <NA>
# 4                     <NA>                                            <NA>
#
#   Disability3  PersonRequiresInterpreter  PersonDependantChildren  \
# ...

# %%
df_index.head()
# Out:
#           PersonDOB Gender        Ethnicity SexualOrientation  \
# PersonID
# 3001     1978-04-11  Woman  White - British        Not stated
# 3002     1998-02-14    NaN       Not stated        Not stated
# 3003     2022-06-24    NaN       Not stated        Not stated
# 3004     2022-06-24    NaN       Not stated        Not stated
# 3005     2022-06-24    NaN       Not stated        Not stated
#
#                       Disability1  \
# PersonID
# 3001      Mental Health Condition
# 3002                         <NA>
# 3003                         <NA>
# 3004                         <NA>
# 3005                         <NA>
#
#                                              Disability2 Disability3  \
# PersonID
# 3001      Physical impairment such as difficulty walking        <NA>
# 3002                                                <NA>        <NA>
# 3003                                                <NA>        <NA>
# ...

# %%
df_index
# Out:
#           PersonDOB             Gender        Ethnicity  SexualOrientation  \
# PersonID
# 3001     1978-04-11              Woman  White - British         Not stated
# 3002     1998-02-14                NaN       Not stated         Not stated
# 3003     2022-06-24                NaN       Not stated         Not stated
# 3004     2022-06-24                NaN       Not stated         Not stated
# 3005     2022-06-24                NaN       Not stated         Not stated
# ...             ...                ...              ...                ...
# 3493     1969-12-22               <NA>       Not stated               <NA>
# 3494     1994-03-31              Woman  White - British         Not stated
# 3495     1982-01-22  Prefer not to say  White - British  Prefer not to say
# 3496     1963-01-29               <NA>       Not stated               <NA>
# 3497     1999-08-01              Woman       Not stated               <NA>
#
#                       Disability1  \
# PersonID
# ...

# %%
#rename columns to more appropriate names

df_index.rename(columns={'DateOfBirth': 'DOB'}, inplace=True)
df_index.rename(columns={'PersonRequiresInterpreter': 'RequiresInterpreter'}, inplace=True)
df_index.rename(columns={'PersonDependantChildren': 'DependantChildren'}, inplace=True)
df_index.rename(columns={'RelationshipToCase': 'CaseRelationship'}, inplace=True)

# %%
df_index
# Out:
#                 DOB             Gender        Ethnicity  SexualOrientation  \
# PersonID
# 3001     1978-04-11              Woman  White - British         Not stated
# 3002     1998-02-14                NaN       Not stated         Not stated
# 3003     2022-06-24                NaN       Not stated         Not stated
# 3004     2022-06-24                NaN       Not stated         Not stated
# 3005     2022-06-24                NaN       Not stated         Not stated
# ...             ...                ...              ...                ...
# 3493     1969-12-22               <NA>       Not stated               <NA>
# 3494     1994-03-31              Woman  White - British         Not stated
# 3495     1982-01-22  Prefer not to say  White - British  Prefer not to say
# 3496     1963-01-29               <NA>       Not stated               <NA>
# 3497     1999-08-01              Woman       Not stated               <NA>
#
#                       Disability1  \
# PersonID
# ...

# %%
df_index['Disability(s)'] = df_index[['Disability1', 'Disability2', 'Disability3']].apply(lambda row: ', '.join(row.dropna().astype(str)), axis=1)

# %%
df_index
# Out:
#                 DOB             Gender        Ethnicity  SexualOrientation  \
# PersonID
# 3001     1978-04-11              Woman  White - British         Not stated
# 3002     1998-02-14                NaN       Not stated         Not stated
# 3003     2022-06-24                NaN       Not stated         Not stated
# 3004     2022-06-24                NaN       Not stated         Not stated
# 3005     2022-06-24                NaN       Not stated         Not stated
# ...             ...                ...              ...                ...
# 3493     1969-12-22               <NA>       Not stated               <NA>
# 3494     1994-03-31              Woman  White - British         Not stated
# 3495     1982-01-22  Prefer not to say  White - British  Prefer not to say
# 3496     1963-01-29               <NA>       Not stated               <NA>
# 3497     1999-08-01              Woman       Not stated               <NA>
#
#                       Disability1  \
# PersonID
# ...

# %%
columns_to_delete = ['Disability1', 'Disability2', 'Disability3']
df_index.drop(columns=columns_to_delete, axis=1, inplace=True)

# %%
df_index
# Out:
#                 DOB             Gender        Ethnicity  SexualOrientation  \
# PersonID
# 3001     1978-04-11              Woman  White - British         Not stated
# 3002     1998-02-14                NaN       Not stated         Not stated
# 3003     2022-06-24                NaN       Not stated         Not stated
# 3004     2022-06-24                NaN       Not stated         Not stated
# 3005     2022-06-24                NaN       Not stated         Not stated
# ...             ...                ...              ...                ...
# 3493     1969-12-22               <NA>       Not stated               <NA>
# 3494     1994-03-31              Woman  White - British         Not stated
# 3495     1982-01-22  Prefer not to say  White - British  Prefer not to say
# 3496     1963-01-29               <NA>       Not stated               <NA>
# 3497     1999-08-01              Woman       Not stated               <NA>
#
# ...

# %%
df_index
# Out:
#                 DOB             Gender        Ethnicity  SexualOrientation  \
# PersonID
# 3001     1978-04-11              Woman  White - British         Not stated
# 3002     1998-02-14                NaN       Not stated         Not stated
# 3003     2022-06-24                NaN       Not stated         Not stated
# 3004     2022-06-24                NaN       Not stated         Not stated
# 3005     2022-06-24                NaN       Not stated         Not stated
# ...             ...                ...              ...                ...
# 3493     1969-12-22               <NA>       Not stated               <NA>
# 3494     1994-03-31              Woman  White - British         Not stated
# 3495     1982-01-22  Prefer not to say  White - British  Prefer not to say
# 3496     1963-01-29               <NA>       Not stated               <NA>
# 3497     1999-08-01              Woman       Not stated               <NA>
#
# ...

# %%
# !pip install pandas-gbq google-auth google-auth-oauthlib google-auth-httplib2

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# Rename the "Disability(s)" column to a valid name
df_index.rename(columns={'Disability(s)': 'Disabilities'}, inplace=True)

# %%
# Out:
#                 DOB             Gender        Ethnicity  SexualOrientation  \
# PersonID
# 3001     1978-04-11              Woman  White - British         Not stated
# 3002     1998-02-14                NaN       Not stated         Not stated
# 3003     2022-06-24                NaN       Not stated         Not stated
# 3004     2022-06-24                NaN       Not stated         Not stated
# 3005     2022-06-24                NaN       Not stated         Not stated
# ...             ...                ...              ...                ...
# 3493     1969-12-22               <NA>       Not stated               <NA>
# 3494     1994-03-31              Woman  White - British         Not stated
# 3495     1982-01-22  Prefer not to say  White - British  Prefer not to say
# 3496     1963-01-29               <NA>       Not stated               <NA>
# 3497     1999-08-01              Woman       Not stated               <NA>
#
# ...
